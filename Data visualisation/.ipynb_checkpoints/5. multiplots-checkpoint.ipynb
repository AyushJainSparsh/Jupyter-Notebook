# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
churn = pd.read_csv("Churn_Modelling.csv")

# %%
churn
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
churn_age_cs = churn.groupby("Age")[["CreditScore","EstimatedSalary"]].mean().reset_index()

# %%
ax1=plt.plot(churn_age_cs["Age"],churn_age_cs["CreditScore"],color="r")
ax2=plt.twinx()
ax2.plot(churn_age_cs["Age"],churn_age_cs["EstimatedSalary"],color="b")

# %%
ax=churn_age_cs.plot.line(x="Age",y="CreditScore")
ax=churn_age_cs.plot.line(x="Age",y="EstimatedSalary",ax=ax,secondary_y=True)

# %%
churn_age_cs_g = churn.groupby(["Age","Gender"])[["CreditScore","EstimatedSalary"]].mean().reset_index()

# %%
churn_age_cs_g
# Out:
#      Age  Gender  CreditScore  EstimatedSalary
# 0     18  Female   673.500000    101225.635000
# 1     18    Male   689.611111     81519.446111
# 2     19  Female   678.111111     97171.375556
# 3     19    Male   659.388889     98015.462778
# 4     20  Female   651.000000     70336.440769
# ..   ...     ...          ...              ...
# 130   84  Female   408.000000    188484.520000
# 131   84    Male   537.000000    186235.980000
# 132   85  Female   787.000000    116537.960000
# 133   88    Male   513.000000     52952.240000
# 134   92    Male   729.000000    115000.410000
#
# [135 rows x 4 columns]

# %%
sns.lineplot(data = churn_age_cs_g , x="Age", y="CreditScore" , hue="Gender")
# Out:
# <Axes: xlabel='Age', ylabel='CreditScore'>

# %%
sns.relplot(data = churn_age_cs_g , x="Age", y="CreditScore" , row="Gender")

# %%
sns.relplot(data = churn_age_cs_g , x="Age", y="CreditScore" , col="Gender")

# %%
sns.relplot(data = churn_age_cs_g , x="Age", y="CreditScore" , col="Gender", kind="line")

# %%
sns.relplot(data = churn , x="Age", y="CreditScore" , col="Gender", row="HasCrCard")

# %%
sns.pairplot(data=churn[["Age","HasCrCard","CreditScore"]])

# %%
#sns.pairplot( data=churn)
